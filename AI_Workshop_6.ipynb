# %% [markdown]
# #TASK 01: Repeat all the task from worksheet - 5 but, try to improve the model from last week with same dataset.
# • Use Data Augmentation to increase the number of training image.
#
# • Use deeper model with BN and DropOut layer as presented above.
#
# • Understand the Model Summary and Training Behavior.
#
# • Use Data Augmentation to increase the number of training image.
#
# • Use deeper model with BN and DropOut layer as presented above.
#
# • Understand the Model Summary and Training Behavior.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import random
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, callbacks
from PIL import Image

# %% [markdown]
# # Data Understanding and Visualization

# %%
train_folder = "/content/drive/MyDrive/ai concept/week5/FruitinAmazon/train"
test_folder = "/content/drive/MyDrive/ai concept/week5/FruitinAmazon/test"

# %%
# Get the list of class directories
class_names = [d for d in os.listdir(train_folder) if os.path.isdir(os.path.join(train_folder, d))]

# Select one random image from each class
selected_images = []
for class_name in class_names:
    class_path = os.path.join(train_folder, class_name)
    images = os.listdir(class_path)

    # Randomly select one image
    if images:
        selected_image = random.choice(images)
        selected_images.append((class_name, os.path.join(class_path, selected_image)))


num_classes = len(selected_images)
cols = (num_classes + 1) // 2

fig, axes = plt.subplots(2, cols, figsize=(10, 6))
axes = axes.flatten()

for i, (class_name, image_path) in enumerate(selected_images):
    img = mpimg.imread(image_path)  # Load image
    axes[i].imshow(img)  # Show image
    axes[i].set_title(class

# Hide unused axes if any
for i in range(len(selected_images), len(axes)):
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# **What did you observe?**
#
# Since the selection is random, running the script multiple times gives different images each time.
#
# The script randomly picks one class folder from the dataset.Then, it randomly selects one image from that class.The image file name and path are printed.

# %% [markdown]
# 2. Check for Corrupted Image: Write a script that verifies whether the image in the train
# directory are valid. If any corrupted images are found, the script must remove the image from
# the directory and print the message which image have been removed, if none found print ”No
# Corrupted Images Found.”

# %%
# Define the path to the train folder
train_folder = "/content/drive/MyDrive/ai concept/week5/FruitinAmazon/train"

# List to keep track of corrupted images
corrupted_images = []

# Iterate through each class subdirectory
for class_name in os.listdir(train_folder):
    class_path = os.path.join(train_folder, class_name)

    if os.path.isdir(class_path):  # Ensure it's a directory
        # Iterate through each image file in the class folder
        for image_name in os.listdir(class_path):
            image_path = os.path.join(class_path, image_name)

            try:
                # Try opening the image
                with Image.open(image_path) as img:
                    img.verify()  # Verify if the image is valid
            except (IOError, SyntaxError):
                # If an error occurs, it means the image is corrupted
                corrupted_images.append(image_path)
                os.remove(image_path)  # Remove the corrupted image
                print(f"Removed corrupted image: {image_path}")

# Check if any corrupted images were found
if not corrupted_images:
    print("No corrupted images found.")
else:
    print(f"Total corrupted images removed: {len(corrupted_images)}")
# Out:
# No corrupted images found.

# %% [markdown]
# # Loading and Preprocessing Image Data in keras

# %%
# Define image size and batch size
img_height = 128 # Example image height
img_width = 128 # Example image width
batch_size = 32
validation_split = 0.2 # 80% training, 20% validation
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
     train_folder, labels='inferred',
     label_mode='int',
     image_size=(img_height, img_width),
     interpolation='nearest',
     batch_size= batch_size,
     shuffle=True,
     validation_split=validation_split,
     subset='training',
     seed=123
)
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.

# %%
# Define image size and batch size
img_height = 128 # Example image height
img_width = 128 # Example image width
batch_size = 32
validation_split = 0.2 # 80% training, 20% validation
# Create a preprocessing layer for normalization
rescale = tf.keras.layers.Rescaling(1./255) # Normalize pixel values to [0, 1]
# Create training dataset with normalization
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_folder,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=True,
    validation_split=validation_split,
    subset='training',
    seed=123
)
# Apply the normalization (Rescaling) to the dataset
train_ds = train_ds.map(lambda x, y: (rescale(x), y))
# Create validation dataset with normalization
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_folder,
    labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size=batch_size,
    shuffle=False,
    validation_split=validation_split,
    subset='validation',
    seed=123
)
# Apply the normalization (Rescaling) to the validation dataset
val_ds = val_ds.map(lambda x, y: (rescale(x), y))
# Out:
# Found 90 files belonging to 6 classes.
# Using 72 files for training.
# Found 90 files belonging to 6 classes.
# Using 18 files for validation.

# %% [markdown]
# #Data augmentation

# %%
import tensorflow as tf
from tensorflow.keras import layers
import matplotlib.pyplot as plt

# Define augmentation (simpler first)
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomContrast(0.1),
    layers.RandomWidth(0.2),  # Stretch width
    layers.RandomHeight(0.2),  # Stretch height
    layers.RandomContrast(0.3),
])


plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
    for i in range(9):
        augmented = data_augmentation(tf.expand_dims(images[i], axis=0), training=True)
        plt.subplot(3, 3, i + 1)
        plt.imshow(tf.clip_by_value(augmented[0], 0, 1).numpy())
        plt.axis("off")
plt.show()

# %% [markdown]
# # Finding image shape

# %%
for image_batch, labels_batch in train_ds.take(1):  # Get one batch
    print(image_batch.shape)  # Prints (batch_size, height, width, channels)
    break
# Out:
# (32, 128, 128, 3)

# %%
input_shape = (32, 128, 128, 3)

# %% [markdown]
# #Applying Batch Normalization

# %%
from tensorflow.keras.layers import BatchNormalization
layer = BatchNormalization(axis=-1, momentum=0.99, epsilon=0.001, center=True, scale=True,
beta_initializer="zeros", gamma_initializer="ones")

# %% [markdown]
# #Applying DropOut

# %%
from tensorflow.keras.layers import Dropout
layer = Dropout(rate=0.25, noise_shape=None, seed=None)

# %% [markdown]
# #Implementing CNN Model

# %%
from tensorflow.keras import models
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

num_classes = len(class_names)

# Define the model
model = models.Sequential([
    # First Convolutional Block
    layers.Conv2D(32, (3, 3), padding='same', activation=None, input_shape=(128, 128, 3)),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Second Convolutional Block
    layers.Conv2D(64, (3, 3), padding='same', activation=None),
    layers.BatchNormalization(),
    layers.Activation('relu'),
    layers.MaxPooling2D((2, 2)),
    layers.Dropout(0.25),

    # Flatten the output of the last Conv2D layer
    layers.Flatten(),

    # Fully Connected Layer
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.25),

    # Output Layer
    layers.Dense(10, activation='softmax')  # Assuming 10 classes
])


model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 65536)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       8,388,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,409,802 (32.08 MB)
#  Trainable params: 8,409,610 (32.08 MB)
#  Non-trainable params: 192 (768.00 B)

# %% [markdown]
# #Compilation and model fit

# %%
inputs = keras.Input(shape=input_shape)

# Compile the model
model.compile(
    optimizer='sgd',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Define callbacks
checkpoint_cb = callbacks.ModelCheckpoint("best_model.h5", save_best_only=True)
early_stopping_cb = callbacks.EarlyStopping(patience=5, restore_best_weights=True)

# Train the model
model.fit(
    train_ds,
    validation_data=val_ds,
    batch_size=8,
    epochs=2000,
    callbacks=[checkpoint_cb, early_stopping_cb],
)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=2000
)

model.summary()
# Out:
# Epoch 1/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8860 - loss: 0.3807
# WARNING:tensorflow:5 out of the last 8031 calls to <function TensorFlowTrainer._make_function.<locals>.multi_step_on_iterator at 0x7d07e876a2a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 8s 2s/step - accuracy: 0.8798 - loss: 0.4198 - val_accuracy: 0.9444 - val_loss: 0.2837
# Epoch 2/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6536 - loss: 14.5512 - val_accuracy: 0.5000 - val_loss: 15.2289
# Epoch 3/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 78ms/step - accuracy: 0.6480 - loss: 1.7455 - val_accuracy: 0.6111 - val_loss: 7.7009
# Epoch 4/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7717 - loss: 1.6853 - val_accuracy: 0.5000 - val_loss: 7.3436
# Epoch 5/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7118 - loss: 0.9509 - val_accuracy: 0.5556 - val_loss: 5.4273
# Epoch 6/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7530 - loss: 1.1505 - val_accuracy: 0.5556 - val_loss: 5.6908
# Epoch 1/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7943 - loss: 9.0074 - val_accuracy: 0.0556 - val_loss: 106.6629
# Epoch 2/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6567 - loss: 7.2855 - val_accuracy: 0.1111 - val_loss: 37.7565
# Epoch 3/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7313 - loss: 1.8786 - val_accuracy: 0.3889 - val_loss: 19.9609
# Epoch 4/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7704 - loss: 3.0845 - val_accuracy: 0.3889 - val_loss: 17.9066
# Epoch 5/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7352 - loss: 2.0187 - val_accuracy: 0.7222 - val_loss: 6.7636
# Epoch 6/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.7539 - loss: 1.2205 - val_accuracy: 0.6111 - val_loss: 6.0236
# Epoch 7/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7157 - loss: 2.0790 - val_accuracy: 0.7778 - val_loss: 3.0022
# Epoch 8/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8355 - loss: 0.9411 - val_accuracy: 0.8333 - val_loss: 1.3264
# Epoch 9/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.7609 - loss: 0.9040 - val_accuracy: 0.8333 - val_loss: 0.4967
# Epoch 10/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - accuracy: 0.6871 - loss: 0.8838 - val_accuracy: 0.8333 - val_loss: 0.3435
# Epoch 11/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6871 - loss: 0.8944 - val_accuracy: 0.7778 - val_loss: 0.5995
# Epoch 12/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.8069 - loss: 0.5222 - val_accuracy: 0.8889 - val_loss: 0.4707
# Epoch 13/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.7812 - loss: 1.4728 - val_accuracy: 0.8889 - val_loss: 0.4188
# Epoch 14/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7852 - loss: 1.3351 - val_accuracy: 0.3889 - val_loss: 5.4827
# Epoch 15/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.6871 - loss: 1.9403 - val_accuracy: 0.5556 - val_loss: 4.4671
# Epoch 16/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7205 - loss: 2.4585 - val_accuracy: 0.6667 - val_loss: 0.6580
# Epoch 17/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.7135 - loss: 1.4474 - val_accuracy: 0.7778 - val_loss: 0.5370
# Epoch 18/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6285 - loss: 1.1170 - val_accuracy: 0.6667 - val_loss: 0.6770
# Epoch 19/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7196 - loss: 0.9133 - val_accuracy: 0.7778 - val_loss: 0.5329
# Epoch 20/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8199 - loss: 0.5736 - val_accuracy: 0.8333 - val_loss: 0.4116
# Epoch 21/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.7717 - loss: 0.7234 - val_accuracy: 0.8889 - val_loss: 0.2943
# Epoch 22/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8533 - loss: 0.4816 - val_accuracy: 0.8333 - val_loss: 0.4393
# Epoch 23/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7943 - loss: 0.5908 - val_accuracy: 0.8333 - val_loss: 0.4880
# Epoch 24/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8377 - loss: 0.5587 - val_accuracy: 0.8889 - val_loss: 0.4218
# Epoch 25/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.7912 - loss: 0.7548 - val_accuracy: 0.8889 - val_loss: 0.5448
# Epoch 26/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8168 - loss: 0.7759 - val_accuracy: 0.8333 - val_loss: 0.4808
# Epoch 27/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8346 - loss: 0.6818 - val_accuracy: 0.6667 - val_loss: 2.3397
# Epoch 28/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - accuracy: 0.7904 - loss: 0.9520 - val_accuracy: 0.8889 - val_loss: 0.5478
# Epoch 29/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.8689 - loss: 0.3756 - val_accuracy: 0.8889 - val_loss: 0.5324
# Epoch 30/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8030 - loss: 1.4472 - val_accuracy: 0.7778 - val_loss: 0.9981
# Epoch 31/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7630 - loss: 1.8553 - val_accuracy: 0.8889 - val_loss: 0.5522
# Epoch 32/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8299 - loss: 0.5052 - val_accuracy: 0.8889 - val_loss: 0.5324
# Epoch 33/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7925 - loss: 0.6939 - val_accuracy: 0.9444 - val_loss: 0.6415
# Epoch 34/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8681 - loss: 0.8921 - val_accuracy: 0.8889 - val_loss: 0.5984
# Epoch 35/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.8346 - loss: 0.9435 - val_accuracy: 0.8889 - val_loss: 0.7282
# Epoch 36/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8689 - loss: 0.6771 - val_accuracy: 0.8333 - val_loss: 0.6682
# Epoch 37/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8286 - loss: 1.6912 - val_accuracy: 0.8333 - val_loss: 0.4768
# Epoch 38/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7726 - loss: 1.9771 - val_accuracy: 0.8889 - val_loss: 0.3718
# Epoch 39/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8021 - loss: 0.7857 - val_accuracy: 0.8889 - val_loss: 0.3993
# Epoch 40/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - accuracy: 0.7639 - loss: 1.3730 - val_accuracy: 0.7778 - val_loss: 0.5690
# Epoch 41/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7990 - loss: 1.1494 - val_accuracy: 0.7778 - val_loss: 0.6428
# Epoch 42/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8021 - loss: 0.5291 - val_accuracy: 0.7778 - val_loss: 0.7365
# Epoch 43/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7609 - loss: 1.3442 - val_accuracy: 0.7778 - val_loss: 0.9699
# Epoch 44/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7990 - loss: 0.9296 - val_accuracy: 0.7778 - val_loss: 0.9899
# Epoch 45/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8346 - loss: 0.4769 - val_accuracy: 0.8333 - val_loss: 0.4151
# Epoch 46/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.7383 - loss: 0.7792 - val_accuracy: 0.8333 - val_loss: 0.5408
# Epoch 47/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.8090 - loss: 0.6821 - val_accuracy: 0.8333 - val_loss: 0.5278
# Epoch 48/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.7990 - loss: 0.6293 - val_accuracy: 0.7778 - val_loss: 0.5795
# Epoch 49/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.6576 - loss: 1.6558 - val_accuracy: 0.7778 - val_loss: 0.6289
# Epoch 50/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.6675 - loss: 1.8088 - val_accuracy: 0.7778 - val_loss: 0.6493
# Epoch 51/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7578 - loss: 1.1891 - val_accuracy: 0.8333 - val_loss: 0.4425
# Epoch 52/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7500 - loss: 0.7231 - val_accuracy: 0.8333 - val_loss: 0.4014
# Epoch 53/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8455 - loss: 0.4415 - val_accuracy: 0.8333 - val_loss: 0.3962
# Epoch 54/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.7561 - loss: 0.6841 - val_accuracy: 0.8333 - val_loss: 0.3871
# Epoch 55/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8307 - loss: 0.4540 - val_accuracy: 0.8333 - val_loss: 0.2494
# Epoch 56/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7174 - loss: 1.0231 - val_accuracy: 0.8333 - val_loss: 0.2623
# Epoch 57/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8424 - loss: 0.9878 - val_accuracy: 0.8889 - val_loss: 0.2110
# Epoch 58/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.8494 - loss: 0.4824 - val_accuracy: 0.8889 - val_loss: 0.2273
# Epoch 59/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7873 - loss: 0.5770 - val_accuracy: 0.8889 - val_loss: 0.2328
# Epoch 60/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.7517 - loss: 1.2007 - val_accuracy: 0.8889 - val_loss: 0.2805
# Epoch 61/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8099 - loss: 0.6686 - val_accuracy: 0.8333 - val_loss: 0.3878
# Epoch 62/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.6949 - loss: 1.2002 - val_accuracy: 0.8333 - val_loss: 0.3535
# Epoch 63/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8051 - loss: 0.6935 - val_accuracy: 0.8333 - val_loss: 0.4053
# Epoch 64/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8433 - loss: 0.3913 - val_accuracy: 0.8333 - val_loss: 0.4116
# Epoch 65/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8307 - loss: 0.5792 - val_accuracy: 0.8333 - val_loss: 0.4895
# Epoch 66/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.7383 - loss: 1.1485 - val_accuracy: 0.8333 - val_loss: 0.4336
# Epoch 67/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7882 - loss: 0.6119 - val_accuracy: 0.8889 - val_loss: 0.1738
# Epoch 68/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7882 - loss: 0.6541 - val_accuracy: 0.8889 - val_loss: 0.1673
# Epoch 69/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.6771 - loss: 0.9772 - val_accuracy: 0.9444 - val_loss: 0.1137
# Epoch 70/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7960 - loss: 1.3613 - val_accuracy: 0.8889 - val_loss: 0.1409
# Epoch 71/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9093 - loss: 0.3969 - val_accuracy: 0.8889 - val_loss: 0.2013
# Epoch 72/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8446 - loss: 0.5226 - val_accuracy: 0.8889 - val_loss: 0.2579
# Epoch 73/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.7617 - loss: 0.7584 - val_accuracy: 0.8333 - val_loss: 0.3004
# Epoch 74/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7904 - loss: 0.5584 - val_accuracy: 0.8889 - val_loss: 0.2576
# Epoch 75/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.6940 - loss: 1.0078 - val_accuracy: 0.8333 - val_loss: 0.2900
# Epoch 76/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8355 - loss: 0.4125 - val_accuracy: 0.8333 - val_loss: 0.3189
# Epoch 77/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.8325 - loss: 0.6663 - val_accuracy: 0.8333 - val_loss: 0.4495
# Epoch 78/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.6801 - loss: 1.1840 - val_accuracy: 0.8333 - val_loss: 0.4791
# Epoch 79/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8277 - loss: 0.4771 - val_accuracy: 0.8333 - val_loss: 0.5471
# Epoch 80/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.8455 - loss: 0.4320 - val_accuracy: 0.8333 - val_loss: 0.5286
# Epoch 81/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8229 - loss: 0.5414 - val_accuracy: 0.8333 - val_loss: 0.5349
# Epoch 82/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.8190 - loss: 0.4502 - val_accuracy: 0.8889 - val_loss: 0.4604
# Epoch 83/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7843 - loss: 0.5806 - val_accuracy: 0.8333 - val_loss: 0.4522
# Epoch 84/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.7852 - loss: 0.9973 - val_accuracy: 0.7778 - val_loss: 0.5432
# Epoch 85/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.7018 - loss: 1.5170 - val_accuracy: 0.8889 - val_loss: 0.2666
# Epoch 86/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8069 - loss: 0.9608 - val_accuracy: 0.8889 - val_loss: 0.1509
# Epoch 87/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6892 - loss: 0.9556 - val_accuracy: 0.8889 - val_loss: 0.1445
# Epoch 88/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.7943 - loss: 0.8280 - val_accuracy: 0.9444 - val_loss: 0.1149
# Epoch 89/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - accuracy: 0.8602 - loss: 0.9539 - val_accuracy: 0.8333 - val_loss: 0.2349
# Epoch 90/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8199 - loss: 0.5436 - val_accuracy: 0.8333 - val_loss: 0.4556
# Epoch 91/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.7591 - loss: 0.7061 - val_accuracy: 0.8333 - val_loss: 0.4656
# Epoch 92/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7964 - loss: 0.7855 - val_accuracy: 0.8889 - val_loss: 0.5594
# Epoch 93/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8563 - loss: 0.3215 - val_accuracy: 0.8333 - val_loss: 0.5073
# Epoch 94/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7283 - loss: 0.8231 - val_accuracy: 0.8333 - val_loss: 0.3907
# Epoch 95/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8346 - loss: 0.7327 - val_accuracy: 0.8333 - val_loss: 0.2150
# Epoch 96/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8238 - loss: 0.4344 - val_accuracy: 0.8333 - val_loss: 0.2384
# Epoch 97/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8168 - loss: 0.5271 - val_accuracy: 0.8333 - val_loss: 0.2664
# Epoch 98/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.9015 - loss: 0.3345 - val_accuracy: 0.8333 - val_loss: 0.2374
# Epoch 99/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8181 - loss: 0.4829 - val_accuracy: 0.8333 - val_loss: 0.2424
# Epoch 100/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8494 - loss: 0.4088 - val_accuracy: 0.8889 - val_loss: 0.2025
# Epoch 101/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8867 - loss: 0.4066 - val_accuracy: 0.8889 - val_loss: 0.4191
# Epoch 102/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8316 - loss: 0.4399 - val_accuracy: 0.8889 - val_loss: 0.4008
# Epoch 103/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.8268 - loss: 0.5510 - val_accuracy: 0.8889 - val_loss: 0.3602
# Epoch 104/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8602 - loss: 0.5731 - val_accuracy: 0.8889 - val_loss: 0.1363
# Epoch 105/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8307 - loss: 0.7318 - val_accuracy: 0.8333 - val_loss: 0.2611
# Epoch 106/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.7483 - loss: 0.5495 - val_accuracy: 0.8333 - val_loss: 0.2534
# Epoch 107/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8533 - loss: 0.3795 - val_accuracy: 0.8333 - val_loss: 0.8002
# Epoch 108/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7882 - loss: 1.0068 - val_accuracy: 0.8889 - val_loss: 0.4245
# Epoch 109/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7305 - loss: 1.1295 - val_accuracy: 0.8889 - val_loss: 0.3987
# Epoch 110/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8681 - loss: 0.4542 - val_accuracy: 0.8889 - val_loss: 0.3860
# Epoch 111/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.7765 - loss: 0.6862 - val_accuracy: 0.8333 - val_loss: 0.2809
# Epoch 112/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 159ms/step - accuracy: 0.9418 - loss: 0.2281 - val_accuracy: 0.8333 - val_loss: 0.2152
# Epoch 113/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.7391 - loss: 0.8729 - val_accuracy: 0.8333 - val_loss: 0.3756
# Epoch 114/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8720 - loss: 1.5758 - val_accuracy: 0.8333 - val_loss: 0.6166
# Epoch 115/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.8446 - loss: 0.5779 - val_accuracy: 0.8333 - val_loss: 0.5494
# Epoch 116/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7374 - loss: 0.6994 - val_accuracy: 0.8333 - val_loss: 0.5160
# Epoch 117/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.7491 - loss: 0.8024 - val_accuracy: 0.9444 - val_loss: 0.0897
# Epoch 118/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8160 - loss: 0.6045 - val_accuracy: 0.9444 - val_loss: 0.5358
# Epoch 119/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8663 - loss: 0.3972 - val_accuracy: 0.9444 - val_loss: 0.4262
# Epoch 120/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8299 - loss: 0.6742 - val_accuracy: 0.9444 - val_loss: 0.3912
# Epoch 121/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8043 - loss: 0.8474 - val_accuracy: 0.9444 - val_loss: 0.3759
# Epoch 122/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8090 - loss: 0.5665 - val_accuracy: 0.9444 - val_loss: 0.4325
# Epoch 123/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8286 - loss: 0.6852 - val_accuracy: 0.9444 - val_loss: 0.3631
# Epoch 124/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7331 - loss: 1.0939 - val_accuracy: 0.9444 - val_loss: 0.3614
# Epoch 125/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8572 - loss: 0.4231 - val_accuracy: 0.8889 - val_loss: 0.4511
# Epoch 126/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8876 - loss: 0.3454 - val_accuracy: 0.8889 - val_loss: 0.4809
# Epoch 127/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8672 - loss: 0.4931 - val_accuracy: 0.8889 - val_loss: 0.4424
# Epoch 128/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.8299 - loss: 1.0127 - val_accuracy: 0.8889 - val_loss: 0.5138
# Epoch 129/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8424 - loss: 0.4746 - val_accuracy: 0.8889 - val_loss: 0.3429
# Epoch 130/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8238 - loss: 0.6815 - val_accuracy: 0.9444 - val_loss: 0.7696
# Epoch 131/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7530 - loss: 0.8265 - val_accuracy: 0.9444 - val_loss: 0.7715
# Epoch 132/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8346 - loss: 0.4462 - val_accuracy: 0.9444 - val_loss: 0.7345
# Epoch 133/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8503 - loss: 0.9164 - val_accuracy: 0.9444 - val_loss: 0.7418
# Epoch 134/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8307 - loss: 0.5496 - val_accuracy: 0.9444 - val_loss: 0.7186
# Epoch 135/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8867 - loss: 0.4520 - val_accuracy: 0.9444 - val_loss: 0.6476
# Epoch 136/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7539 - loss: 0.6796 - val_accuracy: 0.9444 - val_loss: 0.8103
# Epoch 137/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8720 - loss: 0.6774 - val_accuracy: 0.9444 - val_loss: 0.8665
# Epoch 138/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8099 - loss: 1.0285 - val_accuracy: 0.9444 - val_loss: 0.7689
# Epoch 139/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8160 - loss: 0.5815 - val_accuracy: 0.9444 - val_loss: 0.7015
# Epoch 140/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7951 - loss: 0.5388 - val_accuracy: 0.9444 - val_loss: 1.1226
# Epoch 141/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8238 - loss: 0.4685 - val_accuracy: 0.9444 - val_loss: 0.9485
# Epoch 142/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.8789 - loss: 0.3098 - val_accuracy: 0.9444 - val_loss: 0.9707
# Epoch 143/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9054 - loss: 0.3588 - val_accuracy: 0.8889 - val_loss: 1.0023
# Epoch 144/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.8424 - loss: 0.6253 - val_accuracy: 0.9444 - val_loss: 0.6822
# Epoch 145/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.8299 - loss: 0.6356 - val_accuracy: 0.9444 - val_loss: 0.6570
# Epoch 146/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.8485 - loss: 0.5779 - val_accuracy: 0.9444 - val_loss: 0.6594
# Epoch 147/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8455 - loss: 1.0542 - val_accuracy: 0.9444 - val_loss: 0.8855
# Epoch 148/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.8750 - loss: 0.7006 - val_accuracy: 0.8889 - val_loss: 1.2128
# Epoch 149/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7561 - loss: 0.8847 - val_accuracy: 0.9444 - val_loss: 1.0464
# Epoch 150/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8663 - loss: 0.4252 - val_accuracy: 0.8889 - val_loss: 1.0356
# Epoch 151/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8867 - loss: 0.3604 - val_accuracy: 0.9444 - val_loss: 1.1061
# Epoch 152/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8190 - loss: 1.6684 - val_accuracy: 0.9444 - val_loss: 1.0092
# Epoch 153/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.8681 - loss: 0.3635 - val_accuracy: 0.9444 - val_loss: 0.9850
# Epoch 154/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8672 - loss: 0.4272 - val_accuracy: 0.9444 - val_loss: 0.9082
# Epoch 155/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8377 - loss: 0.3738 - val_accuracy: 0.9444 - val_loss: 0.5319
# Epoch 156/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7934 - loss: 0.5503 - val_accuracy: 0.9444 - val_loss: 0.5204
# Epoch 157/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8385 - loss: 0.4050 - val_accuracy: 0.9444 - val_loss: 0.5281
# Epoch 158/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.9193 - loss: 0.2572 - val_accuracy: 0.9444 - val_loss: 0.4659
# Epoch 159/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7374 - loss: 0.6857 - val_accuracy: 0.9444 - val_loss: 0.5537
# Epoch 160/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8859 - loss: 0.3768 - val_accuracy: 0.9444 - val_loss: 0.6356
# Epoch 161/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8121 - loss: 0.4500 - val_accuracy: 0.9444 - val_loss: 0.5571
# Epoch 162/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8090 - loss: 0.8353 - val_accuracy: 0.9444 - val_loss: 0.5485
# Epoch 163/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8958 - loss: 0.4554 - val_accuracy: 0.9444 - val_loss: 0.5542
# Epoch 164/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.8073 - loss: 0.6294 - val_accuracy: 0.9444 - val_loss: 0.8575
# Epoch 165/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.8299 - loss: 0.6307 - val_accuracy: 0.9444 - val_loss: 0.8284
# Epoch 166/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8268 - loss: 0.3750 - val_accuracy: 0.8889 - val_loss: 0.8542
# Epoch 167/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8268 - loss: 0.4412 - val_accuracy: 0.8889 - val_loss: 1.0362
# Epoch 168/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.7244 - loss: 0.7481 - val_accuracy: 0.9444 - val_loss: 0.9853
# Epoch 169/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7934 - loss: 0.5166 - val_accuracy: 0.9444 - val_loss: 0.8626
# Epoch 170/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8741 - loss: 0.2969 - val_accuracy: 0.9444 - val_loss: 0.8253
# Epoch 171/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8828 - loss: 0.5687 - val_accuracy: 0.9444 - val_loss: 0.7651
# Epoch 172/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.9054 - loss: 0.1979 - val_accuracy: 0.9444 - val_loss: 0.7735
# Epoch 173/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.8524 - loss: 0.4242 - val_accuracy: 0.9444 - val_loss: 0.7231
# Epoch 174/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.9349 - loss: 0.2621 - val_accuracy: 0.9444 - val_loss: 0.6374
# Epoch 175/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.8385 - loss: 0.4945 - val_accuracy: 0.9444 - val_loss: 0.5954
# Epoch 176/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 135ms/step - accuracy: 0.8563 - loss: 0.5844 - val_accuracy: 0.9444 - val_loss: 0.6170
# Epoch 177/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.8181 - loss: 0.5312 - val_accuracy: 0.9444 - val_loss: 0.5744
# Epoch 178/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - accuracy: 0.8720 - loss: 0.5206 - val_accuracy: 0.9444 - val_loss: 0.4261
# Epoch 179/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - accuracy: 0.8455 - loss: 0.3664 - val_accuracy: 0.9444 - val_loss: 0.3716
# Epoch 180/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.7964 - loss: 0.6912 - val_accuracy: 0.9444 - val_loss: 0.2978
# Epoch 181/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9006 - loss: 0.3361 - val_accuracy: 0.9444 - val_loss: 0.3062
# Epoch 182/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.7656 - loss: 0.8637 - val_accuracy: 0.9444 - val_loss: 0.2334
# Epoch 183/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7639 - loss: 0.7244 - val_accuracy: 0.9444 - val_loss: 0.2464
# Epoch 184/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.7904 - loss: 0.8859 - val_accuracy: 0.9444 - val_loss: 0.2733
# Epoch 185/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8424 - loss: 0.4557 - val_accuracy: 0.9444 - val_loss: 0.2302
# Epoch 186/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8503 - loss: 0.5283 - val_accuracy: 0.9444 - val_loss: 0.3322
# Epoch 187/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8524 - loss: 0.3844 - val_accuracy: 0.9444 - val_loss: 0.3776
# Epoch 188/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8455 - loss: 0.4376 - val_accuracy: 0.9444 - val_loss: 0.3701
# Epoch 189/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.8377 - loss: 0.5388 - val_accuracy: 0.9444 - val_loss: 0.2263
# Epoch 190/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8720 - loss: 0.4111 - val_accuracy: 0.9444 - val_loss: 0.2605
# Epoch 191/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8711 - loss: 0.3824 - val_accuracy: 0.9444 - val_loss: 0.2898
# Epoch 192/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8494 - loss: 0.4043 - val_accuracy: 0.9444 - val_loss: 0.3108
# Epoch 193/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8247 - loss: 0.5056 - val_accuracy: 0.8889 - val_loss: 0.5023
# Epoch 194/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8789 - loss: 0.3829 - val_accuracy: 0.8889 - val_loss: 0.4764
# Epoch 195/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7778 - loss: 0.5231 - val_accuracy: 0.8889 - val_loss: 0.3848
# Epoch 196/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8485 - loss: 0.5050 - val_accuracy: 0.9444 - val_loss: 0.2666
# Epoch 197/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8533 - loss: 0.3772 - val_accuracy: 0.9444 - val_loss: 0.2925
# Epoch 198/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8129 - loss: 0.3816 - val_accuracy: 0.9444 - val_loss: 0.3034
# Epoch 199/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8672 - loss: 0.5072 - val_accuracy: 0.8889 - val_loss: 0.3281
# Epoch 200/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8346 - loss: 0.4924 - val_accuracy: 0.8889 - val_loss: 0.2950
# Epoch 201/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8641 - loss: 0.4406 - val_accuracy: 0.8889 - val_loss: 0.2954
# Epoch 202/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8286 - loss: 0.5866 - val_accuracy: 0.9444 - val_loss: 0.6832
# Epoch 203/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8533 - loss: 0.6816 - val_accuracy: 0.9444 - val_loss: 0.6002
# Epoch 204/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.8828 - loss: 0.3069 - val_accuracy: 0.9444 - val_loss: 0.5526
# Epoch 205/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.7808 - loss: 0.7460 - val_accuracy: 0.9444 - val_loss: 0.6297
# Epoch 206/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7786 - loss: 0.6295 - val_accuracy: 0.9444 - val_loss: 0.6253
# Epoch 207/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - accuracy: 0.7600 - loss: 0.5780 - val_accuracy: 0.8889 - val_loss: 0.6286
# Epoch 208/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.8542 - loss: 0.5248 - val_accuracy: 0.8889 - val_loss: 0.6227
# Epoch 209/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.7964 - loss: 0.5177 - val_accuracy: 0.8889 - val_loss: 0.6246
# Epoch 210/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - accuracy: 0.9193 - loss: 0.2347 - val_accuracy: 0.8889 - val_loss: 0.5957
# Epoch 211/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.9427 - loss: 0.2164 - val_accuracy: 0.8889 - val_loss: 0.5803
# Epoch 212/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step - accuracy: 0.8229 - loss: 0.4464 - val_accuracy: 0.8889 - val_loss: 0.5814
# Epoch 213/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8424 - loss: 0.6505 - val_accuracy: 0.8889 - val_loss: 0.6192
# Epoch 214/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.9240 - loss: 0.2656 - val_accuracy: 0.8889 - val_loss: 0.6762
# Epoch 215/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8485 - loss: 0.3452 - val_accuracy: 0.8889 - val_loss: 0.6758
# Epoch 216/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.8494 - loss: 0.4011 - val_accuracy: 0.8889 - val_loss: 0.6497
# Epoch 217/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7708 - loss: 0.6513 - val_accuracy: 0.8889 - val_loss: 0.6242
# Epoch 218/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - accuracy: 0.8485 - loss: 0.4196 - val_accuracy: 0.8889 - val_loss: 0.6557
# Epoch 219/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - accuracy: 0.8572 - loss: 0.3748 - val_accuracy: 0.8889 - val_loss: 0.6483
# Epoch 220/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.9332 - loss: 0.2221 - val_accuracy: 0.8889 - val_loss: 0.6299
# Epoch 221/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8277 - loss: 0.4366 - val_accuracy: 0.8889 - val_loss: 0.6230
# Epoch 222/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8207 - loss: 0.5345 - val_accuracy: 0.8333 - val_loss: 0.6394
# Epoch 223/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.7708 - loss: 0.7631 - val_accuracy: 0.8889 - val_loss: 0.5045
# Epoch 224/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8424 - loss: 0.4725 - val_accuracy: 0.8889 - val_loss: 0.4864
# Epoch 225/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8277 - loss: 0.4745 - val_accuracy: 0.8889 - val_loss: 0.5012
# Epoch 226/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.7904 - loss: 0.4978 - val_accuracy: 0.8889 - val_loss: 0.4459
# Epoch 227/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.8937 - loss: 0.2568 - val_accuracy: 0.8333 - val_loss: 0.5616
# Epoch 228/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8563 - loss: 0.3828 - val_accuracy: 0.8889 - val_loss: 0.4165
# Epoch 229/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8377 - loss: 0.4710 - val_accuracy: 0.8889 - val_loss: 0.3936
# Epoch 230/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.7895 - loss: 0.6435 - val_accuracy: 0.8889 - val_loss: 0.4444
# Epoch 231/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.8099 - loss: 0.4434 - val_accuracy: 0.8889 - val_loss: 0.3813
# Epoch 232/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7964 - loss: 0.6317 - val_accuracy: 0.8889 - val_loss: 0.3701
# Epoch 233/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8494 - loss: 1.0050 - val_accuracy: 0.8889 - val_loss: 0.4276
# Epoch 234/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8268 - loss: 0.6516 - val_accuracy: 0.8889 - val_loss: 0.5689
# Epoch 235/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8533 - loss: 0.3358 - val_accuracy: 0.8889 - val_loss: 0.5532
# Epoch 236/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8967 - loss: 0.3115 - val_accuracy: 0.8889 - val_loss: 0.5178
# Epoch 237/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8464 - loss: 0.4435 - val_accuracy: 0.8333 - val_loss: 0.7081
# Epoch 238/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8859 - loss: 0.3000 - val_accuracy: 0.8333 - val_loss: 0.7186
# Epoch 239/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8906 - loss: 0.6657 - val_accuracy: 0.8889 - val_loss: 0.4879
# Epoch 240/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8494 - loss: 1.5980 - val_accuracy: 0.8333 - val_loss: 1.6533
# Epoch 241/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8121 - loss: 1.1081 - val_accuracy: 0.8333 - val_loss: 1.6099
# Epoch 242/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.8268 - loss: 0.7377 - val_accuracy: 0.8889 - val_loss: 1.3613
# Epoch 243/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8099 - loss: 0.6025 - val_accuracy: 0.9444 - val_loss: 1.1334
# Epoch 244/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - accuracy: 0.7765 - loss: 0.5902 - val_accuracy: 0.9444 - val_loss: 0.7527
# Epoch 245/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7951 - loss: 0.5381 - val_accuracy: 0.9444 - val_loss: 0.6912
# Epoch 246/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.8681 - loss: 0.3368 - val_accuracy: 0.9444 - val_loss: 0.5988
# Epoch 247/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8385 - loss: 0.4346 - val_accuracy: 0.9444 - val_loss: 0.4742
# Epoch 248/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8750 - loss: 0.3679 - val_accuracy: 0.9444 - val_loss: 0.4507
# Epoch 249/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.8129 - loss: 0.4426 - val_accuracy: 0.8889 - val_loss: 0.4124
# Epoch 250/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - accuracy: 0.8572 - loss: 0.5882 - val_accuracy: 0.8889 - val_loss: 0.4704
# Epoch 251/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.7786 - loss: 0.7946 - val_accuracy: 0.8889 - val_loss: 0.4718
# Epoch 252/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8837 - loss: 0.8026 - val_accuracy: 0.8889 - val_loss: 0.5310
# Epoch 253/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8789 - loss: 0.3498 - val_accuracy: 0.8889 - val_loss: 0.5234
# Epoch 254/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.7982 - loss: 0.8082 - val_accuracy: 0.8889 - val_loss: 0.5457
# Epoch 255/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7609 - loss: 0.6716 - val_accuracy: 0.8889 - val_loss: 0.3974
# Epoch 256/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8828 - loss: 0.4164 - val_accuracy: 0.8889 - val_loss: 0.3706
# Epoch 257/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - accuracy: 0.7600 - loss: 0.7868 - val_accuracy: 0.8889 - val_loss: 0.3581
# Epoch 258/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8043 - loss: 0.4337 - val_accuracy: 0.8889 - val_loss: 0.3385
# Epoch 259/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8906 - loss: 0.4352 - val_accuracy: 0.8889 - val_loss: 0.3433
# Epoch 260/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8151 - loss: 0.6168 - val_accuracy: 0.8889 - val_loss: 0.3448
# Epoch 261/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.7856 - loss: 0.7088 - val_accuracy: 0.8889 - val_loss: 0.3310
# Epoch 262/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8043 - loss: 0.8305 - val_accuracy: 0.8889 - val_loss: 0.3334
# Epoch 263/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8021 - loss: 0.5040 - val_accuracy: 0.8333 - val_loss: 0.4118
# Epoch 264/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8485 - loss: 0.3618 - val_accuracy: 0.8889 - val_loss: 0.3118
# Epoch 265/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8672 - loss: 0.3994 - val_accuracy: 0.8889 - val_loss: 0.3457
# Epoch 266/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.7856 - loss: 0.4575 - val_accuracy: 0.8889 - val_loss: 0.3281
# Epoch 267/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.9232 - loss: 0.2166 - val_accuracy: 0.8889 - val_loss: 0.3305
# Epoch 268/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8572 - loss: 0.4318 - val_accuracy: 0.8889 - val_loss: 0.3362
# Epoch 269/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8759 - loss: 0.3975 - val_accuracy: 0.8889 - val_loss: 0.3516
# Epoch 270/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8307 - loss: 0.4305 - val_accuracy: 0.8889 - val_loss: 0.4259
# Epoch 271/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.8216 - loss: 0.8469 - val_accuracy: 0.8889 - val_loss: 0.5325
# Epoch 272/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8563 - loss: 0.4985 - val_accuracy: 0.8333 - val_loss: 0.9628
# Epoch 273/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8051 - loss: 0.5611 - val_accuracy: 0.8333 - val_loss: 0.6237
# Epoch 274/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.8268 - loss: 1.1761 - val_accuracy: 0.7778 - val_loss: 0.5502
# Epoch 275/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.7730 - loss: 0.7642 - val_accuracy: 0.7778 - val_loss: 0.5386
# Epoch 276/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8494 - loss: 0.8051 - val_accuracy: 0.8333 - val_loss: 0.3797
# Epoch 277/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8672 - loss: 0.3764 - val_accuracy: 0.7778 - val_loss: 0.5445
# Epoch 278/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.8168 - loss: 0.5728 - val_accuracy: 0.5556 - val_loss: 0.9793
# Epoch 279/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.8355 - loss: 0.4449 - val_accuracy: 0.5556 - val_loss: 0.9665
# Epoch 280/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - accuracy: 0.8177 - loss: 0.6200 - val_accuracy: 0.5556 - val_loss: 0.9938
# Epoch 281/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.7726 - loss: 0.6896 - val_accuracy: 0.6111 - val_loss: 0.9332
# Epoch 282/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.8168 - loss: 0.4508 - val_accuracy: 0.6111 - val_loss: 0.9016
# Epoch 283/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - accuracy: 0.8494 - loss: 0.6792 - val_accuracy: 0.6111 - val_loss: 0.9081
# Epoch 284/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8563 - loss: 0.5280 - val_accuracy: 0.6667 - val_loss: 0.7840
# Epoch 285/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.7739 - loss: 0.6541 - val_accuracy: 0.7222 - val_loss: 0.6257
# Epoch 286/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8611 - loss: 0.5656 - val_accuracy: 0.8889 - val_loss: 0.2820
# Epoch 287/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8316 - loss: 0.4889 - val_accuracy: 0.9444 - val_loss: 0.2409
# Epoch 288/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.8859 - loss: 0.3719 - val_accuracy: 0.8889 - val_loss: 0.4134
# Epoch 289/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 92ms/step - accuracy: 0.8346 - loss: 0.4810 - val_accuracy: 0.9444 - val_loss: 0.2416
# Epoch 290/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8268 - loss: 0.5834 - val_accuracy: 0.7778 - val_loss: 2.0824
# Epoch 291/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.8238 - loss: 0.4748 - val_accuracy: 0.7778 - val_loss: 2.0988
# Epoch 292/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8060 - loss: 3.2052 - val_accuracy: 0.7778 - val_loss: 1.1640
# Epoch 293/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7522 - loss: 1.0507 - val_accuracy: 0.7778 - val_loss: 0.9797
# Epoch 294/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8898 - loss: 0.3259 - val_accuracy: 0.7778 - val_loss: 1.0562
# Epoch 295/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9210 - loss: 0.6824 - val_accuracy: 0.8889 - val_loss: 0.5244
# Epoch 296/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8346 - loss: 0.6979 - val_accuracy: 0.8889 - val_loss: 0.2783
# Epoch 297/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - accuracy: 0.8485 - loss: 0.3995 - val_accuracy: 0.8889 - val_loss: 0.2682
# Epoch 298/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8043 - loss: 0.3720 - val_accuracy: 0.9444 - val_loss: 0.2197
# Epoch 299/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.8260 - loss: 0.4946 - val_accuracy: 0.8889 - val_loss: 0.2987
# Epoch 300/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.9154 - loss: 0.1927 - val_accuracy: 0.8333 - val_loss: 0.3020
# Epoch 301/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8533 - loss: 0.5074 - val_accuracy: 0.8333 - val_loss: 0.3091
# Epoch 302/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8307 - loss: 0.4650 - val_accuracy: 0.8333 - val_loss: 0.3222
# Epoch 303/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8368 - loss: 0.4284 - val_accuracy: 0.7778 - val_loss: 0.3886
# Epoch 304/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9115 - loss: 0.3258 - val_accuracy: 0.8889 - val_loss: 0.2840
# Epoch 305/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - accuracy: 0.9054 - loss: 0.3137 - val_accuracy: 0.8333 - val_loss: 0.3051
# Epoch 306/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.8346 - loss: 0.5251 - val_accuracy: 0.8889 - val_loss: 0.2907
# Epoch 307/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8542 - loss: 0.3668 - val_accuracy: 0.8889 - val_loss: 0.2751
# Epoch 308/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8850 - loss: 0.3674 - val_accuracy: 0.8333 - val_loss: 0.3024
# Epoch 309/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.8976 - loss: 0.3107 - val_accuracy: 0.8333 - val_loss: 0.3021
# Epoch 310/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8012 - loss: 0.5287 - val_accuracy: 0.8889 - val_loss: 0.2865
# Epoch 311/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 87ms/step - accuracy: 0.9154 - loss: 0.7596 - val_accuracy: 0.8333 - val_loss: 0.3444
# Epoch 312/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 157ms/step - accuracy: 0.8798 - loss: 0.3029 - val_accuracy: 0.8333 - val_loss: 0.3451
# Epoch 313/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.7040 - loss: 0.7600 - val_accuracy: 0.8889 - val_loss: 0.2759
# Epoch 314/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 134ms/step - accuracy: 0.8485 - loss: 0.5817 - val_accuracy: 0.8333 - val_loss: 0.4136
# Epoch 315/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step - accuracy: 0.8442 - loss: 0.5009 - val_accuracy: 0.8889 - val_loss: 0.2848
# Epoch 316/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8229 - loss: 0.7555 - val_accuracy: 0.8889 - val_loss: 0.2985
# Epoch 317/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.8641 - loss: 0.3410 - val_accuracy: 0.8889 - val_loss: 0.3040
# Epoch 318/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - accuracy: 0.7717 - loss: 1.3601 - val_accuracy: 0.8333 - val_loss: 0.3530
# Epoch 319/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.7856 - loss: 0.5610 - val_accuracy: 0.8333 - val_loss: 0.3597
# Epoch 320/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8633 - loss: 0.3817 - val_accuracy: 0.8333 - val_loss: 0.3571
# Epoch 321/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8377 - loss: 0.4566 - val_accuracy: 0.8889 - val_loss: 0.3055
# Epoch 322/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 85ms/step - accuracy: 0.8034 - loss: 1.0571 - val_accuracy: 0.8889 - val_loss: 0.3947
# Epoch 323/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8689 - loss: 0.3633 - val_accuracy: 0.8889 - val_loss: 0.3624
# Epoch 324/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.7964 - loss: 0.5670 - val_accuracy: 0.8889 - val_loss: 0.4244
# Epoch 325/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8277 - loss: 0.5181 - val_accuracy: 0.8889 - val_loss: 0.3888
# Epoch 326/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.7982 - loss: 0.5939 - val_accuracy: 0.8889 - val_loss: 0.5117
# Epoch 327/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.8594 - loss: 0.3980 - val_accuracy: 0.8889 - val_loss: 0.5142
# Epoch 328/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9171 - loss: 0.2384 - val_accuracy: 0.8889 - val_loss: 0.5050
# Epoch 329/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8129 - loss: 0.4852 - val_accuracy: 0.8889 - val_loss: 0.5143
# Epoch 330/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step - accuracy: 0.8533 - loss: 0.4597 - val_accuracy: 0.8889 - val_loss: 0.4960
# Epoch 331/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.8641 - loss: 0.3678 - val_accuracy: 0.8889 - val_loss: 0.4793
# Epoch 332/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.8355 - loss: 0.4927 - val_accuracy: 0.8889 - val_loss: 0.5611
# Epoch 333/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - accuracy: 0.8268 - loss: 0.4026 - val_accuracy: 0.8889 - val_loss: 0.5364
# Epoch 334/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.9054 - loss: 0.5046 - val_accuracy: 0.8889 - val_loss: 0.4929
# Epoch 335/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8446 - loss: 0.3554 - val_accuracy: 0.8889 - val_loss: 0.4333
# Epoch 336/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.8407 - loss: 0.4121 - val_accuracy: 0.8889 - val_loss: 0.4543
# Epoch 337/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - accuracy: 0.8346 - loss: 0.4477 - val_accuracy: 0.8889 - val_loss: 0.4907
# Epoch 338/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.8876 - loss: 0.2963 - val_accuracy: 0.8889 - val_loss: 0.4775
# Epoch 339/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8151 - loss: 0.4680 - val_accuracy: 0.8889 - val_loss: 0.4724
# Epoch 340/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9115 - loss: 0.2404 - val_accuracy: 0.8889 - val_loss: 0.5321
# Epoch 341/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.9006 - loss: 0.5060 - val_accuracy: 0.8889 - val_loss: 0.3561
# Epoch 342/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step - accuracy: 0.8385 - loss: 0.4556 - val_accuracy: 0.8889 - val_loss: 0.2995
# Epoch 343/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.7904 - loss: 0.6448 - val_accuracy: 0.8333 - val_loss: 0.3922
# Epoch 344/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.7756 - loss: 0.7462 - val_accuracy: 0.8889 - val_loss: 0.2281
# Epoch 345/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8572 - loss: 0.4891 - val_accuracy: 0.9444 - val_loss: 0.2092
# Epoch 346/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.7826 - loss: 0.6229 - val_accuracy: 0.9444 - val_loss: 0.2546
# Epoch 347/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.8720 - loss: 0.3403 - val_accuracy: 0.9444 - val_loss: 0.2505
# Epoch 348/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.8594 - loss: 0.3425 - val_accuracy: 0.8889 - val_loss: 0.2574
# Epoch 349/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.8641 - loss: 0.5920 - val_accuracy: 0.9444 - val_loss: 0.2610
# Epoch 350/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.8772 - loss: 0.5346 - val_accuracy: 0.9444 - val_loss: 0.2788
# Epoch 351/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.8720 - loss: 0.3243 - val_accuracy: 0.9444 - val_loss: 0.2787
# Epoch 352/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8611 - loss: 0.4592 - val_accuracy: 0.9444 - val_loss: 0.2814
# Epoch 353/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.8681 - loss: 0.3056 - val_accuracy: 0.9444 - val_loss: 0.3175
# Epoch 354/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9015 - loss: 0.3305 - val_accuracy: 0.9444 - val_loss: 0.2665
# Epoch 355/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.8268 - loss: 0.4319 - val_accuracy: 0.9444 - val_loss: 0.2733
# Epoch 356/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.8268 - loss: 0.8769 - val_accuracy: 0.8889 - val_loss: 0.3231
# Epoch 357/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.9054 - loss: 0.2934 - val_accuracy: 0.8889 - val_loss: 0.2680
# Epoch 358/2000
# ...
# Epoch 1903/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8190 - loss: 0.2914 - val_accuracy: 0.8333 - val_loss: 0.3418
# Epoch 1904/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8741 - loss: 0.2561 - val_accuracy: 0.8333 - val_loss: 0.3455
# Epoch 1905/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.8260 - loss: 0.3833 - val_accuracy: 0.8333 - val_loss: 0.3447
# Epoch 1906/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step - accuracy: 0.8641 - loss: 0.2823 - val_accuracy: 0.8333 - val_loss: 0.3465
# Epoch 1907/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8681 - loss: 0.2771 - val_accuracy: 0.8333 - val_loss: 0.3341
# Epoch 1908/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8928 - loss: 0.3206 - val_accuracy: 0.8333 - val_loss: 0.3300
# Epoch 1909/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.9262 - loss: 0.1918 - val_accuracy: 0.8333 - val_loss: 0.3306
# Epoch 1910/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8121 - loss: 0.3575 - val_accuracy: 0.8333 - val_loss: 0.3614
# Epoch 1911/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.8602 - loss: 0.3420 - val_accuracy: 0.8333 - val_loss: 0.3621
# Epoch 1912/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 160ms/step - accuracy: 0.8594 - loss: 0.2964 - val_accuracy: 0.8333 - val_loss: 0.3511
# Epoch 1913/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 154ms/step - accuracy: 0.8898 - loss: 0.2620 - val_accuracy: 0.8333 - val_loss: 0.3503
# Epoch 1914/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 172ms/step - accuracy: 0.7973 - loss: 0.4351 - val_accuracy: 0.8333 - val_loss: 0.3451
# Epoch 1915/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.9271 - loss: 0.1756 - val_accuracy: 0.8333 - val_loss: 0.3465
# Epoch 1916/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8641 - loss: 0.2877 - val_accuracy: 0.8333 - val_loss: 0.3723
# Epoch 1917/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.8928 - loss: 0.2538 - val_accuracy: 0.8333 - val_loss: 0.4284
# Epoch 1918/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 136ms/step - accuracy: 0.8859 - loss: 0.2854 - val_accuracy: 0.8333 - val_loss: 0.3722
# Epoch 1919/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9115 - loss: 0.1914 - val_accuracy: 0.8333 - val_loss: 0.3776
# Epoch 1920/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8416 - loss: 0.3229 - val_accuracy: 0.8333 - val_loss: 0.3972
# Epoch 1921/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8711 - loss: 0.2900 - val_accuracy: 0.8333 - val_loss: 0.4373
# Epoch 1922/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9410 - loss: 0.1655 - val_accuracy: 0.8333 - val_loss: 0.4319
# Epoch 1923/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9271 - loss: 0.1614 - val_accuracy: 0.8333 - val_loss: 0.4357
# Epoch 1924/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.8789 - loss: 0.2639 - val_accuracy: 0.8333 - val_loss: 0.4483
# Epoch 1925/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - accuracy: 0.9162 - loss: 0.2042 - val_accuracy: 0.8333 - val_loss: 0.4658
# Epoch 1926/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.8711 - loss: 0.2665 - val_accuracy: 0.8333 - val_loss: 0.4299
# Epoch 1927/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.9015 - loss: 0.2140 - val_accuracy: 0.8333 - val_loss: 0.4386
# Epoch 1928/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.8976 - loss: 0.2411 - val_accuracy: 0.8333 - val_loss: 0.4216
# Epoch 1929/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.8798 - loss: 0.2448 - val_accuracy: 0.8333 - val_loss: 0.4248
# Epoch 1930/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.8898 - loss: 0.2815 - val_accuracy: 0.8333 - val_loss: 0.3875
# Epoch 1931/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - accuracy: 0.9154 - loss: 0.2328 - val_accuracy: 0.8333 - val_loss: 0.3591
# Epoch 1932/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.8928 - loss: 0.2546 - val_accuracy: 0.8333 - val_loss: 0.3484
# Epoch 1933/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.8967 - loss: 0.2503 - val_accuracy: 0.8889 - val_loss: 0.3714
# Epoch 1934/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 111ms/step - accuracy: 0.8455 - loss: 0.3487 - val_accuracy: 0.8333 - val_loss: 0.4221
# Epoch 1935/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8945 - loss: 0.2620 - val_accuracy: 0.8333 - val_loss: 0.4273
# Epoch 1936/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.8711 - loss: 0.3776 - val_accuracy: 0.8333 - val_loss: 0.3972
# Epoch 1937/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 145ms/step - accuracy: 0.8633 - loss: 0.2548 - val_accuracy: 0.8333 - val_loss: 0.5000
# Epoch 1938/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 158ms/step - accuracy: 0.8455 - loss: 0.3512 - val_accuracy: 0.8333 - val_loss: 0.4978
# Epoch 1939/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.8190 - loss: 0.4177 - val_accuracy: 0.8333 - val_loss: 0.2865
# Epoch 1940/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 148ms/step - accuracy: 0.8424 - loss: 0.3176 - val_accuracy: 0.8333 - val_loss: 0.2868
# Epoch 1941/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.9596 - loss: 0.1540 - val_accuracy: 0.8333 - val_loss: 0.2840
# Epoch 1942/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8633 - loss: 0.3020 - val_accuracy: 0.8333 - val_loss: 0.2816
# Epoch 1943/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.8976 - loss: 0.1968 - val_accuracy: 0.8333 - val_loss: 0.2560
# Epoch 1944/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - accuracy: 0.9349 - loss: 0.1858 - val_accuracy: 0.8333 - val_loss: 0.2541
# Epoch 1945/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9449 - loss: 0.2403 - val_accuracy: 0.8889 - val_loss: 0.2324
# Epoch 1946/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.8672 - loss: 0.3471 - val_accuracy: 0.8333 - val_loss: 0.2376
# Epoch 1947/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8937 - loss: 0.2683 - val_accuracy: 0.8333 - val_loss: 0.2809
# Epoch 1948/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.9076 - loss: 0.2087 - val_accuracy: 0.8333 - val_loss: 0.2865
# Epoch 1949/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.8416 - loss: 0.3567 - val_accuracy: 0.8333 - val_loss: 0.3081
# Epoch 1950/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8898 - loss: 0.2480 - val_accuracy: 0.8333 - val_loss: 0.3484
# Epoch 1951/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9084 - loss: 0.2304 - val_accuracy: 0.8333 - val_loss: 0.3474
# Epoch 1952/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8828 - loss: 0.2681 - val_accuracy: 0.8333 - val_loss: 0.3819
# Epoch 1953/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.7591 - loss: 0.5363 - val_accuracy: 0.8333 - val_loss: 0.3919
# Epoch 1954/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8741 - loss: 0.3037 - val_accuracy: 0.8333 - val_loss: 0.4026
# Epoch 1955/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8789 - loss: 0.2879 - val_accuracy: 0.8333 - val_loss: 0.4366
# Epoch 1956/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 147ms/step - accuracy: 0.8082 - loss: 0.3976 - val_accuracy: 0.8333 - val_loss: 0.4088
# Epoch 1957/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 0.8346 - loss: 0.3486 - val_accuracy: 0.8333 - val_loss: 0.3826
# Epoch 1958/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.9527 - loss: 0.1611 - val_accuracy: 0.8333 - val_loss: 0.3589
# Epoch 1959/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.8633 - loss: 0.2737 - val_accuracy: 0.8333 - val_loss: 0.3909
# Epoch 1960/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.9154 - loss: 0.2593 - val_accuracy: 0.8333 - val_loss: 0.4142
# Epoch 1961/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.9193 - loss: 0.2339 - val_accuracy: 0.8333 - val_loss: 0.3970
# Epoch 1962/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.8681 - loss: 0.3060 - val_accuracy: 0.8333 - val_loss: 0.3963
# Epoch 1963/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.9006 - loss: 0.2535 - val_accuracy: 0.8333 - val_loss: 0.3937
# Epoch 1964/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.9223 - loss: 0.1780 - val_accuracy: 0.8333 - val_loss: 0.3807
# Epoch 1965/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 0.8819 - loss: 0.2809 - val_accuracy: 0.8333 - val_loss: 0.3727
# Epoch 1966/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 168ms/step - accuracy: 0.9006 - loss: 0.2573 - val_accuracy: 0.8333 - val_loss: 0.3765
# Epoch 1967/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 176ms/step - accuracy: 0.7778 - loss: 0.5103 - val_accuracy: 0.8333 - val_loss: 0.3703
# Epoch 1968/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.8867 - loss: 0.2883 - val_accuracy: 0.8333 - val_loss: 0.3019
# Epoch 1969/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8898 - loss: 0.2496 - val_accuracy: 0.8333 - val_loss: 0.2959
# Epoch 1970/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.8876 - loss: 0.2505 - val_accuracy: 0.8333 - val_loss: 0.2768
# Epoch 1971/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 141ms/step - accuracy: 0.8464 - loss: 0.3129 - val_accuracy: 0.8333 - val_loss: 0.2857
# Epoch 1972/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - accuracy: 0.8477 - loss: 0.2414 - val_accuracy: 0.8333 - val_loss: 0.2659
# Epoch 1973/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9596 - loss: 0.1234 - val_accuracy: 0.8333 - val_loss: 0.2581
# Epoch 1974/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8338 - loss: 0.3165 - val_accuracy: 0.8333 - val_loss: 0.2821
# Epoch 1975/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.9201 - loss: 0.2267 - val_accuracy: 0.8333 - val_loss: 0.2816
# Epoch 1976/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.8819 - loss: 0.3128 - val_accuracy: 0.8333 - val_loss: 0.2690
# Epoch 1977/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.7786 - loss: 0.4572 - val_accuracy: 0.8333 - val_loss: 0.2684
# Epoch 1978/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - accuracy: 0.8446 - loss: 0.3035 - val_accuracy: 0.8333 - val_loss: 0.2833
# Epoch 1979/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - accuracy: 0.8720 - loss: 0.3214 - val_accuracy: 0.8333 - val_loss: 0.2814
# Epoch 1980/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - accuracy: 0.9115 - loss: 0.2254 - val_accuracy: 0.8333 - val_loss: 0.2596
# Epoch 1981/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8602 - loss: 0.3022 - val_accuracy: 0.8333 - val_loss: 0.2589
# Epoch 1982/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.8681 - loss: 0.3067 - val_accuracy: 0.8333 - val_loss: 0.2850
# Epoch 1983/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.8503 - loss: 0.3408 - val_accuracy: 0.8333 - val_loss: 0.2833
# Epoch 1984/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.8385 - loss: 0.3175 - val_accuracy: 0.8333 - val_loss: 0.3193
# Epoch 1985/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9223 - loss: 0.2018 - val_accuracy: 0.8333 - val_loss: 0.3275
# Epoch 1986/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.8837 - loss: 0.2626 - val_accuracy: 0.8333 - val_loss: 0.3284
# Epoch 1987/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step - accuracy: 0.9418 - loss: 0.2327 - val_accuracy: 0.8333 - val_loss: 0.3450
# Epoch 1988/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 182ms/step - accuracy: 0.9076 - loss: 0.2101 - val_accuracy: 0.8333 - val_loss: 0.2889
# Epoch 1989/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.8602 - loss: 0.3483 - val_accuracy: 0.8333 - val_loss: 0.3097
# Epoch 1990/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - accuracy: 0.8819 - loss: 0.3156 - val_accuracy: 0.9444 - val_loss: 0.0876
# Epoch 1991/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.9301 - loss: 0.1712 - val_accuracy: 0.9444 - val_loss: 0.0910
# Epoch 1992/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 164ms/step - accuracy: 0.8299 - loss: 0.4345 - val_accuracy: 0.9444 - val_loss: 0.0960
# Epoch 1993/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.9635 - loss: 0.1187 - val_accuracy: 0.9444 - val_loss: 0.1010
# Epoch 1994/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.8433 - loss: 0.3092 - val_accuracy: 0.9444 - val_loss: 0.1027
# Epoch 1995/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.8720 - loss: 0.2832 - val_accuracy: 0.9444 - val_loss: 0.1053
# Epoch 1996/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.8750 - loss: 0.2608 - val_accuracy: 0.9444 - val_loss: 0.1212
# Epoch 1997/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.8207 - loss: 0.3799 - val_accuracy: 0.9444 - val_loss: 0.1152
# Epoch 1998/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.8984 - loss: 0.2121 - val_accuracy: 0.9444 - val_loss: 0.1180
# Epoch 1999/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.8594 - loss: 0.3024 - val_accuracy: 0.9444 - val_loss: 0.1365
# Epoch 2000/2000
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - accuracy: 0.9557 - loss: 0.1233 - val_accuracy: 0.9444 - val_loss: 0.1217
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 128, 128, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_1                │ (None, 128, 128, 32)        │             128 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation (Activation)              │ (None, 128, 128, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64, 64, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 64, 64, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 64, 64, 64)          │             256 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ activation_1 (Activation)            │ (None, 64, 64, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_2 (Dropout)                  │ (None, 32, 32, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 65536)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 128)                 │       8,388,736 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │           1,290 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 8,409,804 (32.08 MB)
#  Trainable params: 8,409,610 (32.08 MB)
#  Non-trainable params: 192 (768.00 B)
#  Optimizer params: 2 (12.00 B)

# %% [markdown]
# # Evaluating the model

# %%
test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_folder, labels='inferred',
    label_mode='int',
    image_size=(img_height, img_width),
    interpolation='nearest',
    batch_size= batch_size,
    shuffle=True,
    validation_split=validation_split,
    subset='training',
    seed=123
  )
# Out:
# Found 30 files belonging to 6 classes.
# Using 24 files for training.

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(test_ds)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.4583 - loss: 816.8564
# Test Loss: 816.8564
# Test Accuracy: 0.4583

# %% [markdown]
# # Save and load the model

# %%
# Save the model
model.save('trained_model.h5')

# Load the model
loaded_model = keras.models.load_model('trained_model.h5')

# Re-evaluate the model on the test set
test_loss, test_accuracy = loaded_model.evaluate(test_ds)
print(f"Test Loss: {test_loss:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 631ms/step - accuracy: 0.4583 - loss: 816.8564
# Test Loss: 816.8564
# Test Accuracy: 0.4583

# %% [markdown]
# # Predictions and Classification reports

# %%
import numpy as np
from sklearn.metrics import classification_report

# Get true labels and predictions
y_true = []
y_pred = []

for images, labels in test_ds:
    y_true.extend(labels.numpy())
    predictions = loaded_model.predict(images)
    y_pred.extend(np.argmax(predictions, axis=1))

# Classification report
print(classification_report(y_true, y_pred, target_names=class_names))

# Plot training history
def plot_history(history):
    plt.figure(figsize=(12, 5))

    # Plot accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()

    # Plot loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

    plt.tight_layout()
    plt.show()

plot_history(history)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.11/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
#               precision    recall  f1-score   support
#
#       tucuma       0.40      1.00      0.57         4
#         acai       0.60      0.75      0.67         4
#     graviola       1.00      0.75      0.86         4
#      cupuacu       0.00      0.00      0.00         3
#      pupunha       0.00      0.00      0.00         5
#      guarana       0.17      0.25      0.20         4
#
#     accuracy                           0.46        24
#    macro avg       0.36      0.46      0.38        24
# weighted avg       0.36      0.46      0.38        24

# %% [markdown]
# #TASK-02: Transfer Learning
# To - Do:
#
# • Implement transfer learning using a pre-trained model trained on ImageNet weights, freeze the
# layers of the model, and fit it only on the output layer to classify the fruits dataset.
#
#
# • Evaluate the model’s performance and generate an inference output and classification report.
#
#
# • Did the performance improved compared to training from scratch.

# %%
from tensorflow.keras.applications import VGG16

# Load VGG16 without the top classification layer
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Freeze all layers so their weights won't change during training
for layer in base_model.layers:
    layer.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense
from tensorflow.keras.models import Model

# Add custom classification layers on top
x = base_model.output
x = GlobalAveragePooling2D()(x)           # Flatten the output
x = Dense(1024, activation='relu')(x)     # Fully connected layer
outputs = Dense(10, activation='softmax')(x)  # Output layer (10 classes)

# Create the full model
model = Model(inputs=base_model.input, outputs=outputs)

# %%
from tensorflow.keras.optimizers import Adam

model.compile(
    optimizer=Adam(),
    loss='sparse_categorical_crossentropy',  # Change to 'categorical_crossentropy' if needed
    metrics=['accuracy']
)

# %%
# If using image_dataset_from_directory
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/AL ML/FruitinAmazon/train',
    image_size=(224, 224),
    batch_size=32
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    '/content/drive/MyDrive/AL ML/FruitinAmazon/train',
    image_size=(224, 224),
    batch_size=32
)
# Out:
# Found 90 files belonging to 6 classes.
# Found 90 files belonging to 6 classes.

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10,
    callbacks=[early_stopping]
)
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 6s/step - accuracy: 0.1674 - loss: 5.8223 - val_accuracy: 0.7556 - val_loss: 1.1921
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 428ms/step - accuracy: 0.7968 - loss: 1.0201 - val_accuracy: 0.8778 - val_loss: 0.6393
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 430ms/step - accuracy: 0.8970 - loss: 0.6195 - val_accuracy: 0.9778 - val_loss: 0.1406
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 431ms/step - accuracy: 0.9850 - loss: 0.0938 - val_accuracy: 0.9667 - val_loss: 0.0819
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 484ms/step - accuracy: 0.9772 - loss: 0.0619 - val_accuracy: 1.0000 - val_loss: 0.0051
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 486ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 467ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0046
# Epoch 8/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 465ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 9/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 422ms/step - accuracy: 1.0000 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 0.0016

# %%
import matplotlib.pyplot as plt

# Plot accuracy
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
